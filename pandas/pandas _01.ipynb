# %%
import pandas as pd

# %% [markdown]
# LOAD DATA

# %%
data = pd.read_csv('Data/sales.csv')

# %%
data.head()
# Out:
#         State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0  California            63.0        Amaretto  109.0  Major Market  -131.0
# 1  California            55.0       Green Tea  201.0  Major Market    88.0
# 2  California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3  California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4  California            37.0       Chamomile  247.0  Major Market   148.0
#
#   Market  Marketing Product Type  Inventory     Type
# 0   West         40       Coffee     2947.0  Regular
# 1   West         24          Tea      659.0  Regular
# 2   West        109     Espresso      788.0  Regular
# 3   West         81     Espresso     1744.0    Decaf
# 4   West         26   Herbal Tea      809.0    Decaf

# %%
data.tail()
# Out:
#           State  Total Expenses     Product  Sales   Market Size  Profit  \
# 4236  Wisconsin            34.0  Darjeeling   90.0  Small Market    20.0
# 4237  Wisconsin            36.0  Darjeeling  113.0  Small Market    31.0
# 4238  Wisconsin            86.0   Earl Grey  150.0  Small Market     1.0
# 4239  Wisconsin            79.0   Earl Grey  131.0  Small Market    -3.0
# 4240  Wisconsin            87.0   Earl Grey  165.0  Small Market     4.0
#
#        Market  Marketing Product Type  Inventory     Type
# 4236  Central         11          Tea      458.0  Regular
# 4237  Central         14          Tea      454.0  Regular
# 4238  Central         57          Tea      506.0  Regular
# 4239  Central         49          Tea      627.0  Regular
# 4240  Central         58          Tea      513.0  Regular

# %%
data.shape
# Out:
# (4241, 11)

# %% [markdown]
# # pandas dataframe and series

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.describe()
# Out:
#        Total Expenses        Sales       Profit    Marketing    Inventory
# count     4238.000000  4239.000000  4235.000000  4241.000000  4240.000000
# mean        53.989146   192.567351    60.840614    31.124499   747.971226
# std         32.295812   150.563621   101.301672    26.983618   660.498475
# min         10.000000    17.000000  -638.000000     0.000000 -3534.000000
# 25%         33.000000   100.000000    17.000000    13.000000   431.500000
# 50%         46.000000   138.000000    40.000000    22.000000   619.000000
# 75%         65.000000   230.000000    92.000000    39.000000   901.000000
# max        190.000000   912.000000   778.000000   156.000000  8252.000000

# %%
insects = ["Ants", "Cricket", "Bee"]

# %%
type(insects)
# Out:
# list

# %%
data_insects = pd.DataFrame(insects, columns=['Insects'])

# %%
data_insects
# Out:
#    Insects
# 0     Ants
# 1  Cricket
# 2      Bee

# %%
animals = {'Mammals' : ['Cow', 'Sheep', 'Lion'],
           'Reptiles' : ['Crocodile', 'Lizard', 'Snake'],
           'Insects' : ['Ants', 'Cricket', 'Bee']}

# %%
type(animals)
# Out:
# dict

# %%
data_animals = pd.DataFrame(animals)

# %%
data_animals
# Out:
#   Mammals   Reptiles  Insects
# 0     Cow  Crocodile     Ants
# 1   Sheep     Lizard  Cricket
# 2    Lion      Snake      Bee

# %%
data_animals['Mammals']
# Out:
# 0      Cow
# 1    Sheep
# 2     Lion
# Name: Mammals, dtype: object

# %%
data_animals.Reptiles
# Out:
# 0    Crocodile
# 1       Lizard
# 2        Snake
# Name: Reptiles, dtype: object

# %%
type(data_animals.Reptiles)
# Out:
# pandas.core.series.Series

# %%
type(data_animals)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data_animals['Mammals'])
# Out:
# pandas.core.series.Series

# %%
data_animals.iloc[0]
# Out:
# Mammals           Cow
# Reptiles    Crocodile
# Insects          Ants
# Name: 0, dtype: object

# %%
type(data_animals.iloc[0])
# Out:
# pandas.core.series.Series

# %%
data_animals.iloc[[0, 1]]
# Out:
#   Mammals   Reptiles  Insects
# 0     Cow  Crocodile     Ants
# 1   Sheep     Lizard  Cricket

# %%
type(data_animals.iloc[[0, 1]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # INDEXES

# %%
data.iloc[4]
# Out:
# State               California
# Total Expenses            37.0
# Product              Chamomile
# Sales                    247.0
# Market Size       Major Market
# Profit                   148.0
# Market                    West
# Marketing                   26
# Product Type        Herbal Tea
# Inventory                809.0
# Type                     Decaf
# Name: 4, dtype: object

# %%
# data.loc['California']

# %%
new_data = data.head()

# %%
new_data
# Out:
#         State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0  California            63.0        Amaretto  109.0  Major Market  -131.0
# 1  California            55.0       Green Tea  201.0  Major Market    88.0
# 2  California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3  California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4  California            37.0       Chamomile  247.0  Major Market   148.0
#
#   Market  Marketing Product Type  Inventory     Type
# 0   West         40       Coffee     2947.0  Regular
# 1   West         24          Tea      659.0  Regular
# 2   West        109     Espresso      788.0  Regular
# 3   West         81     Espresso     1744.0    Decaf
# 4   West         26   Herbal Tea      809.0    Decaf

# %%
indexes = ['One', 'Two', 'Three', 'Four', 'Five']

# %%
new_data.set_index([indexes], inplace=True)
new_data
# Out:
#             State  Total Expenses         Product  Sales   Market Size  \
# One    California            63.0        Amaretto  109.0  Major Market
# Two    California            55.0       Green Tea  201.0  Major Market
# Three  California           143.0     Caffe Mocha  289.0  Major Market
# Four   California           113.0  Decaf Espresso  576.0  Major Market
# Five   California            37.0       Chamomile  247.0  Major Market
#
#        Profit Market  Marketing Product Type  Inventory     Type
# One    -131.0   West         40       Coffee     2947.0  Regular
# Two      88.0   West         24          Tea      659.0  Regular
# Three    25.0   West        109     Espresso      788.0  Regular
# Four    216.0   West         81     Espresso     1744.0    Decaf
# Five    148.0   West         26   Herbal Tea      809.0    Decaf

# %%
new_data.loc['Four']
# Out:
# State                 California
# Total Expenses             113.0
# Product           Decaf Espresso
# Sales                      576.0
# Market Size         Major Market
# Profit                     216.0
# Market                      West
# Marketing                     81
# Product Type            Espresso
# Inventory                 1744.0
# Type                       Decaf
# Name: Four, dtype: object

# %%
type(new_data.loc)
# Out:
# pandas.core.indexing._LocIndexer

# %%
type(new_data.loc['Four'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # FILTERING DATA

# %%
data
# Out:
#            State  Total Expenses         Product  Sales   Market Size  Profit  \
# 0     California            63.0        Amaretto  109.0  Major Market  -131.0
# 1     California            55.0       Green Tea  201.0  Major Market    88.0
# 2     California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4     California            37.0       Chamomile  247.0  Major Market   148.0
# ...          ...             ...             ...    ...           ...     ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market    20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market    31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market     1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market    -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market     4.0
#
# ...

# %%
highest_sales = (data['Sales'] > 300)
highest_sales
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 4236    False
# 4237    False
# 4238    False
# 4239    False
# 4240    False
# Name: Sales, Length: 4241, dtype: bool

# %%
data.loc[highest_sales]
# Out:
#            State  Total Expenses         Product  Sales   Market Size  Profit  \
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 5     California            99.0           Lemon  582.0  Major Market   291.0
# 9     California           142.0       Columbian  687.0  Major Market   364.0
# 10    California           166.0       Columbian  902.0  Major Market   508.0
# 11    California           139.0       Columbian  664.0  Major Market   349.0
# ...          ...             ...             ...    ...           ...     ...
# 3932  Washington            71.0       Chamomile  329.0  Small Market   171.0
# 3933  Washington            73.0       Chamomile  334.0  Small Market   171.0
# 4004  Washington            75.0       Chamomile  347.0  Small Market   179.0
# 4122   Wisconsin           149.0       Columbian  317.0  Small Market    35.0
# 4213   Wisconsin           139.0       Columbian  314.0  Small Market    48.0
#
# ...

# %%
data.loc[highest_sales, ['Product', 'Profit', 'Sales']]
# Out:
#              Product  Profit  Sales
# 3     Decaf Espresso   216.0  576.0
# 5              Lemon   291.0  582.0
# 9          Columbian   364.0  687.0
# 10         Columbian   508.0  902.0
# 11         Columbian   349.0  664.0
# ...              ...     ...    ...
# 3932       Chamomile   171.0  329.0
# 3933       Chamomile   171.0  334.0
# 4004       Chamomile   179.0  347.0
# 4122       Columbian    35.0  317.0
# 4213       Columbian    48.0  314.0
#
# [669 rows x 3 columns]

# %%
data['Product'].unique()
# Out:
# array(['Amaretto', 'Green Tea', 'Caffe Mocha', 'Decaf Espresso',
#        'Chamomile', 'Lemon', 'Mint', 'Darjeeling', 'Earl Grey',
#        'Columbian', 'Caffe Latte', 'Decaf Irish Cream',
#        'Regular Espresso'], dtype=object)

# %%
product = ['Green Tea', 'Lemon', 'Mint']

# %%
filt = data['Product'].isin(product)

# %%
data.loc[filt]
# Out:
#            State  Total Expenses    Product  Sales   Market Size  Profit  \
# 1     California            55.0  Green Tea  201.0  Major Market    88.0
# 5     California            99.0      Lemon  582.0  Major Market   291.0
# 6     California            25.0       Mint   90.0  Major Market    26.0
# 12    California            54.0  Green Tea  168.0  Major Market    47.0
# 17    California            88.0      Lemon  467.0  Major Market   165.0
# ...          ...             ...        ...    ...           ...     ...
# 4193   Wisconsin            25.0      Lemon  143.0  Small Market    80.0
# 4194   Wisconsin            20.0      Lemon   83.0  Small Market    40.0
# 4195   Wisconsin            21.0      Lemon   91.0  Small Market    45.0
# 4230   Wisconsin            27.0      Lemon  144.0  Small Market    58.0
# 4231   Wisconsin            25.0      Lemon  123.0  Small Market    64.0
#
#        Market  Marketing Product Type  Inventory     Type
# ...

# %% [markdown]
# # UPDATING ROWS AND COLUMNS

# %%
data.columns.str.replace(' ', '_')
# Out:
# Index(['State', 'Total_Expenses', 'Product', 'Sales', 'Market_Size', 'Profit',
#        'Market', 'Marketing', 'Product_Type', 'Inventory', 'Type'],
#       dtype='object')

# %%
data.columns = data.columns.str.replace(' ', '_')

# %%
data.head()
# Out:
#         State  Total_Expenses         Product  Sales   Market_Size  Profit  \
# 0  California            63.0        Amaretto  109.0  Major Market  -131.0
# 1  California            55.0       Green Tea  201.0  Major Market    88.0
# 2  California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3  California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4  California            37.0       Chamomile  247.0  Major Market   148.0
#
#   Market  Marketing Product_Type  Inventory     Type
# 0   West         40       Coffee     2947.0  Regular
# 1   West         24          Tea      659.0  Regular
# 2   West        109     Espresso      788.0  Regular
# 3   West         81     Espresso     1744.0    Decaf
# 4   West         26   Herbal Tea      809.0    Decaf

# %%
data.Product_Type
# Out:
# 0           Coffee
# 1              Tea
# 2         Espresso
# 3         Espresso
# 4       Herbal Tea
#            ...
# 4236           Tea
# 4237           Tea
# 4238           Tea
# 4239           Tea
# 4240           Tea
# Name: Product_Type, Length: 4241, dtype: object

# %%
data.rename(columns={'Marketing':'Trade'}, inplace=True)
data
# Out:
#            State  Total_Expenses         Product  Sales   Market_Size  Profit  \
# 0     California            63.0        Amaretto  109.0  Major Market  -131.0
# 1     California            55.0       Green Tea  201.0  Major Market    88.0
# 2     California           143.0     Caffe Mocha  289.0  Major Market    25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4     California            37.0       Chamomile  247.0  Major Market   148.0
# ...          ...             ...             ...    ...           ...     ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market    20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market    31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market     1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market    -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market     4.0
#
# ...

# %%
data.loc[2, 'Total_Expenses'] = 500

# %%
data
# Out:
#            State  Total_Expenses         Product  Sales   Market_Size  Profit  \
# 0     California            63.0        Amaretto  109.0  Major Market  -131.0
# 1     California            55.0       Green Tea  201.0  Major Market    88.0
# 2     California           500.0     Caffe Mocha  289.0  Major Market    25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4     California            37.0       Chamomile  247.0  Major Market   148.0
# ...          ...             ...             ...    ...           ...     ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market    20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market    31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market     1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market    -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market     4.0
#
# ...

# %%
data.at[2, 'Total_Expenses'] = 700

# %%
data
# Out:
#            State  Total_Expenses         Product  Sales   Market_Size  Profit  \
# 0     California            63.0        Amaretto  109.0  Major Market  -131.0
# 1     California            55.0       Green Tea  201.0  Major Market    88.0
# 2     California           700.0     Caffe Mocha  289.0  Major Market    25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4     California            37.0       Chamomile  247.0  Major Market   148.0
# ...          ...             ...             ...    ...           ...     ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market    20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market    31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market     1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market    -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market     4.0
#
# ...

# %% [markdown]
# # ADDING / REMOVING ROWS / COLUMNS

# %%
new_column = data['Total_Expenses'] + data['Sales']
data['New_Column'] = new_column
data
# Out:
#            State  Total_Expenses         Product  Sales   Market_Size  Profit  \
# 0     California            63.0        Amaretto  109.0  Major Market  -131.0
# 1     California            55.0       Green Tea  201.0  Major Market    88.0
# 2     California           700.0     Caffe Mocha  289.0  Major Market    25.0
# 3     California           113.0  Decaf Espresso  576.0  Major Market   216.0
# 4     California            37.0       Chamomile  247.0  Major Market   148.0
# ...          ...             ...             ...    ...           ...     ...
# 4236   Wisconsin            34.0      Darjeeling   90.0  Small Market    20.0
# 4237   Wisconsin            36.0      Darjeeling  113.0  Small Market    31.0
# 4238   Wisconsin            86.0       Earl Grey  150.0  Small Market     1.0
# 4239   Wisconsin            79.0       Earl Grey  131.0  Small Market    -3.0
# 4240   Wisconsin            87.0       Earl Grey  165.0  Small Market     4.0
#
# ...

# %%
data.drop(columns = ['Product', 'Market_Size'], inplace=True)

# %%
data
# Out:
#            State  Total_Expenses  Sales  Profit   Market  Trade Product_Type  \
# 0     California            63.0  109.0  -131.0     West     40       Coffee
# 1     California            55.0  201.0    88.0     West     24          Tea
# 2     California           700.0  289.0    25.0     West    109     Espresso
# 3     California           113.0  576.0   216.0     West     81     Espresso
# 4     California            37.0  247.0   148.0     West     26   Herbal Tea
# ...          ...             ...    ...     ...      ...    ...          ...
# 4236   Wisconsin            34.0   90.0    20.0  Central     11          Tea
# 4237   Wisconsin            36.0  113.0    31.0  Central     14          Tea
# 4238   Wisconsin            86.0  150.0     1.0  Central     57          Tea
# 4239   Wisconsin            79.0  131.0    -3.0  Central     49          Tea
# 4240   Wisconsin            87.0  165.0     4.0  Central     58          Tea
#
#       Inventory     Type  New_Column
# ...

# %%
data.drop(index=0)
# Out:
#            State  Total_Expenses  Sales  Profit   Market  Trade Product_Type  \
# 1     California            55.0  201.0    88.0     West     24          Tea
# 2     California           700.0  289.0    25.0     West    109     Espresso
# 3     California           113.0  576.0   216.0     West     81     Espresso
# 4     California            37.0  247.0   148.0     West     26   Herbal Tea
# 5     California            99.0  582.0   291.0     West     77   Herbal Tea
# ...          ...             ...    ...     ...      ...    ...          ...
# 4236   Wisconsin            34.0   90.0    20.0  Central     11          Tea
# 4237   Wisconsin            36.0  113.0    31.0  Central     14          Tea
# 4238   Wisconsin            86.0  150.0     1.0  Central     57          Tea
# 4239   Wisconsin            79.0  131.0    -3.0  Central     49          Tea
# 4240   Wisconsin            87.0  165.0     4.0  Central     58          Tea
#
#       Inventory     Type  New_Column
# ...

# %% [markdown]
# # DATA SORTING

# %%
data.sort_values(by='Sales')
# Out:
#            State  Total_Expenses  Sales  Profit   Market  Trade Product_Type  \
# 1914      Nevada           126.0   17.0  -354.0     West     93          Tea
# 1923      Nevada           124.0   18.0  -524.0     West    100          Tea
# 1917      Nevada           133.0   18.0  -380.0     West    100          Tea
# 2036      Nevada           132.0   19.0  -552.0     West     93          Tea
# 2034      Nevada           147.0   19.0  -430.0     West    114          Tea
# ...          ...             ...    ...     ...      ...    ...          ...
# 131   California           178.0  910.0   368.0     West    127       Coffee
# 2644    New York           178.0  912.0   370.0     East    127       Coffee
# 157   California           178.0  912.0   370.0     West    127       Coffee
# 502     Colorado            54.0    NaN    80.0  Central     23     Espresso
# 508     Colorado            71.0    NaN    99.0  Central     47   Herbal Tea
#
#       Inventory     Type  New_Column
# ...

# %%
data.sort_values(by=['Sales', 'Trade'], ascending=True)
# Out:
#            State  Total_Expenses  Sales  Profit   Market  Trade Product_Type  \
# 1914      Nevada           126.0   17.0  -354.0     West     93          Tea
# 1917      Nevada           133.0   18.0  -380.0     West    100          Tea
# 1923      Nevada           124.0   18.0  -524.0     West    100          Tea
# 2036      Nevada           132.0   19.0  -552.0     West     93          Tea
# 2034      Nevada           147.0   19.0  -430.0     West    114          Tea
# ...          ...             ...    ...     ...      ...    ...          ...
# 2645    New York           178.0  910.0   368.0     East    127       Coffee
# 157   California           178.0  912.0   370.0     West    127       Coffee
# 2644    New York           178.0  912.0   370.0     East    127       Coffee
# 502     Colorado            54.0    NaN    80.0  Central     23     Espresso
# 508     Colorado            71.0    NaN    99.0  Central     47   Herbal Tea
#
#       Inventory     Type  New_Column
# ...

# %%
data.sort_index(ascending=False)
# Out:
#            State  Total_Expenses  Sales  Profit   Market  Trade Product_Type  \
# 4240   Wisconsin            87.0  165.0     4.0  Central     58          Tea
# 4239   Wisconsin            79.0  131.0    -3.0  Central     49          Tea
# 4238   Wisconsin            86.0  150.0     1.0  Central     57          Tea
# 4237   Wisconsin            36.0  113.0    31.0  Central     14          Tea
# 4236   Wisconsin            34.0   90.0    20.0  Central     11          Tea
# ...          ...             ...    ...     ...      ...    ...          ...
# 4     California            37.0  247.0   148.0     West     26   Herbal Tea
# 3     California           113.0  576.0   216.0     West     81     Espresso
# 2     California           700.0  289.0    25.0     West    109     Espresso
# 1     California            55.0  201.0    88.0     West     24          Tea
# 0     California            63.0  109.0  -131.0     West     40       Coffee
#
#       Inventory     Type  New_Column
# ...

# %%
data.sort_index(ascending=True)
# Out:
#            State  Total_Expenses  Sales  Profit   Market  Trade Product_Type  \
# 0     California            63.0  109.0  -131.0     West     40       Coffee
# 1     California            55.0  201.0    88.0     West     24          Tea
# 2     California           700.0  289.0    25.0     West    109     Espresso
# 3     California           113.0  576.0   216.0     West     81     Espresso
# 4     California            37.0  247.0   148.0     West     26   Herbal Tea
# ...          ...             ...    ...     ...      ...    ...          ...
# 4236   Wisconsin            34.0   90.0    20.0  Central     11          Tea
# 4237   Wisconsin            36.0  113.0    31.0  Central     14          Tea
# 4238   Wisconsin            86.0  150.0     1.0  Central     57          Tea
# 4239   Wisconsin            79.0  131.0    -3.0  Central     49          Tea
# 4240   Wisconsin            87.0  165.0     4.0  Central     58          Tea
#
#       Inventory     Type  New_Column
# ...

# %%
data['Market'].sort_values()
# Out:
# 4240    Central
# 1224    Central
# 1223    Central
# 1222    Central
# 1221    Central
#          ...
# 2142       West
# 2141       West
# 2140       West
# 2150       West
# 2120       West
# Name: Market, Length: 4241, dtype: object

# %%
data['New_Column'].sort_values()
# Out:
# 1291    38.0
# 1292    39.0
# 1159    39.0
# 1296    40.0
# 1335    41.0
#         ...
# 290      NaN
# 302      NaN
# 502      NaN
# 508      NaN
# 514      NaN
# Name: New_Column, Length: 4241, dtype: float64

# %%
type(data['New_Column'].sort_values())
# Out:
# pandas.core.series.Series

# %% [markdown]
# # CLEANING AND SAVING PANDAS DATAFRAMES

# %%
data.isnull().sum()
# Out:
# State             0
# Total_Expenses    3
# Sales             2
# Profit            6
# Market            0
# Trade             0
# Product_Type      0
# Inventory         1
# Type              0
# New_Column        5
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# State             0
# Total_Expenses    0
# Sales             0
# Profit            0
# Market            0
# Trade             0
# Product_Type      0
# Inventory         0
# Type              0
# New_Column        0
# dtype: int64

# %%
data.to_csv('New_sales.csv')

# %%
data.to_excel('New_workbook.xlsx')

# %%
grouped = data.groupby('State').agg({'Profit':'mean', 'Sales':'count'})

# %%
grouped
# Out:
#                    Profit  Sales
# State
# California     108.285199    277
# Colorado        66.202335    257
# Connecticut     45.359281    167
# Florida         56.990741    216
# Illinois       142.689815    216
# Iowa           102.833333    216
# Louisiana       43.779762    168
# Massachusetts  114.180556    144
# Missouri        16.671296    216
# Nevada          40.212121    264
# New Hampshire   16.357143    168
# New Mexico       4.755952    168
# New York       104.666667    192
# Ohio            49.875000    216
# Oklahoma        50.940476    168
# Oregon          47.117424    264
# Texas           93.845238    168
# Utah            26.913194    288
# Washington      47.520833    240
# Wisconsin       40.287037    216
